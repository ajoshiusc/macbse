# %%
import glob
import nibabel as nib
import numpy as np
from os.path import isfile
import datetime
import nibabel as nib
import matplotlib.pyplot as plt
from nilearn import plotting
import torch
import monai
from monai.networks.nets import UNet
from monai.losses import DiceLoss
from torch.nn import MSELoss
from monai.data import Dataset, DataLoader, partition_dataset
from monai.transforms.utility.dictionary import SqueezeDimd
from monai.transforms import Compose, LoadImaged, SqueezeDim, SqueezeDimd, ToTensord, LoadImage, ToTensor, EnsureChannelFirstD, EnsureChannelFirst, Resize, RandBiasFieldd
from monai.utils import set_determinism
from glob import glob
import random

# Set random seed for reproducibility
set_determinism(seed=0)

# Define your dataset and data loader
class BiasFieldCorrectionDataset(Dataset):
    def __init__(self, image_files, mask_files, transform=None):
        self.image_files = image_files
        self.mask_files = mask_files
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        image = self.transform(self.image_files[idx])
        mask = self.transform(self.mask_files[idx])
        return {'image': image, 'mask': mask}

# Assuming you have a list of paired image and bias file paths
#image_files = ['image1.nii.gz', 'image2.nii.gz']
#mask_files = ['bias_field1.nii.gz', 'bias_field2.nii.gz']

mask_files = (glob('../../mac_bse_data/data/site-uwo/sub-*/ses-001/anat/sub-*_ses-001_run-1_T1w_mask.nii.gz'))
image_files = [m[:-12]+'.nii.gz' for m in mask_files ]

print('*********************')
print(image_files)
print(mask_files)
print('*********************')

# Define transformations
#transforms = Compose([LoadImaged(keys=['image', 'bias'],image_only=True), AddChanneld(keys=['image', 'bias']), ToTensord(keys=['image', 'bias'])])
#transforms = Compose([LoadImage(image_only=True), Resize(), EnsureChannelFirst(), ToTensor()])


data_dicts = [{"image": image, "mask": mask} for image, mask in zip(image_files, mask_files)]

random.seed(11)

#random.shuffle(data_dicts)
num_files = len(data_dicts)
num_train_files = round(0.8 * num_files)
train_files = data_dicts[:num_train_files]
val_files = data_dicts[num_train_files:]
print("total num files:", len(data_dicts))
print("num training files:", len(train_files))
print("num validation files:", len(val_files))

from monai.transforms import Compose, Resized, RandBiasFieldd, ScaleIntensityd,LoadImaged, EnsureChannelFirstd, RandAffined, ToTensord,LoadImage,ToTensor,EnsureChannelFirstD,EnsureChannelFirst, Resize, RandBiasFieldd
from monai.data import (
    CacheDataset,
    DataLoader,
    Dataset,
    pad_list_data_collate,
    TestTimeAugmentation,
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

keys = ["image", "mask"]

train_transforms = Compose([
    LoadImaged(keys,image_only=True),
    EnsureChannelFirstd(keys),
    ScaleIntensityd(keys="image", minv=0.0, maxv=1.0),
    Resized(
            keys,
            spatial_size=(64, 64, 64),
            mode='trilinear',
    ),
    RandAffined(
            keys,
            prob=0.5,
            #rotate_range=(np.pi / 18, np.pi / 18, np.pi / 18),
            rotate_range=(np.pi / 6, np.pi / 6, np.pi / 6),
            #translate_range=(5,5,5),
            translate_range=(15,15,15),
            scale_range=(0.3,0.3,0.3),
            shear_range=(.1,.1,.1,.1,.1,.1),
            padding_mode=("zeros","reflection"),
        ),
    RandBiasFieldd(keys="image",prob=0.5, coeff_range=(-1,1), degree=5),
])


val_transforms = Compose([
    LoadImaged(keys,image_only=True),
    EnsureChannelFirstd(keys),
    ScaleIntensityd(keys="image", minv=0.0, maxv=1.0),
    Resized(
            keys,
            spatial_size=(64, 64, 64),
            mode='trilinear',
    ),
])

train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=4)
train_loader = DataLoader(train_ds, batch_size=4, num_workers=10, collate_fn=pad_list_data_collate)
val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=4)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=10, collate_fn=pad_list_data_collate)

batch = next(iter(train_loader))

i=0
for batch in train_loader:
    i += 1
    if i>20:
        break

    #for j in range(4):
    #    print(j)
    #    plt.subplot(121)
    #    plt.imshow(batch['image'][j,0,:,32,:],cmap='gray',vmin=0,vmax=1)
    #    plt.subplot(122)
    #    plt.imshow(batch['mask'][j,0,:,32,:],cmap='gray',vmin=-10,vmax=10)

    #    plt.show()

# Create dataset and data loader
#dataset = BiasFieldCorrectionDataset(image_files, mask_files, transform=transforms)


# Split the dataset into training and validation sets


# Create data loaders for training and validation
#train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True)
#val_loader = DataLoader(val_dataset, batch_size=2, shuffle=False)

# Define the UNet model and optimizer

# Specify spatial_dims and strides for 3D data
spatial_dims = 3
strides = (1, 1, 1, 1)

model = UNet(
    spatial_dims=spatial_dims,
    in_channels=1,  # Adjust based on your data
    out_channels=1, # Adjust based on your data
    channels=(16, 64, 64, 128, 256),#(2,8,8,16,32),#(16, 64, 64, 128, 256),
    strides=strides,
).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# Define the Dice loss
loss_function = MSELoss() # DiceLoss(sigmoid=True)

# Training loop
num_epochs = 202
save_interval = 5

train_loss_epoch = np.zeros(num_epochs)
val_loss_epoch = np.zeros(num_epochs)

for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0.0

    for batch in train_loader:

        inputs, masks = batch['image'].to(device), batch['mask'].to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = loss_function(outputs, masks)

        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()

    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {total_train_loss / len(train_files)}")
    train_loss_epoch[epoch] = total_train_loss / len(train_files)


    # Validation loop
    model.eval()
    total_val_loss = 0.0

    with torch.no_grad():
        for batch in val_loader:
            inputs, masks = batch['image'].to(device), batch['mask'].to(device)
            outputs = model(inputs)
            loss = loss_function(outputs, masks)
            total_val_loss += loss.item()

    print(f"Epoch {epoch+1}/{num_epochs}, Validation Loss: {total_val_loss / len(val_files)}")
    val_loss_epoch[epoch] = total_val_loss / len(val_files)


    if epoch % save_interval == 0:

        current_datetime = datetime.datetime.now()

        # Format the date and time as a string
        formatted_datetime = current_datetime.strftime("%Y-%m-%d_%H-%M-%S")

        # Create a filename with the formatted date and time
        filename = f"models/bias_field_correction_model_{formatted_datetime}_epoch_{epoch}.pth"

        # Save the trained model
        torch.save(model.state_dict(), filename)
        filename = f"models/bias_field_correction_loss_{formatted_datetime}_epoch_{epoch}.npz"

        np.savez(filename,val_loss_epoch=val_loss_epoch,train_loss_epoch=train_loss_epoch)

print('Training is done!')
# Out:
# *********************
# ['../../mac_bse_data/data/site-uwo/sub-032193/ses-001/anat/sub-032193_ses-001_run-1_T1w.nii.gz', '../../mac_bse_data/data/site-uwo/sub-032195/ses-001/anat/sub-032195_ses-001_run-1_T1w.nii.gz', '../../mac_bse_data/data/site-uwo/sub-032196/ses-001/anat/sub-032196_ses-001_run-1_T1w.nii.gz']
# ['../../mac_bse_data/data/site-uwo/sub-032193/ses-001/anat/sub-032193_ses-001_run-1_T1w_mask.nii.gz', '../../mac_bse_data/data/site-uwo/sub-032195/ses-001/anat/sub-032195_ses-001_run-1_T1w_mask.nii.gz', '../../mac_bse_data/data/site-uwo/sub-032196/ses-001/anat/sub-032196_ses-001_run-1_T1w_mask.nii.gz']
# *********************
# total num files: 3
# num training files: 2
# num validation files: 1
# Loading dataset: 100%|██████████| 2/2 [00:03<00:00,  1.65s/it]
# Loading dataset: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# Epoch 1/202, Training Loss: 3.8117449283599854
# Epoch 1/202, Validation Loss: 4.374420642852783
# Epoch 2/202, Training Loss: 2.256706714630127
# Epoch 2/202, Validation Loss: 3.1932947635650635
# Epoch 3/202, Training Loss: 1.3999353647232056
# Epoch 3/202, Validation Loss: 1.8433916568756104
# Epoch 4/202, Training Loss: 0.6675097942352295
# Epoch 4/202, Validation Loss: 1.2996435165405273
# Epoch 5/202, Training Loss: 0.577296257019043
# Epoch 5/202, Validation Loss: 1.2665534019470215
# Epoch 6/202, Training Loss: 0.5278955101966858
# Epoch 6/202, Validation Loss: 1.2182700634002686
# Epoch 7/202, Training Loss: 0.5673110485076904
# Epoch 7/202, Validation Loss: 1.111870527267456
# Epoch 8/202, Training Loss: 0.4683271050453186
# Epoch 8/202, Validation Loss: 1.012542486190796
# Epoch 9/202, Training Loss: 0.3872792720794678
# Epoch 9/202, Validation Loss: 0.9439949989318848
# Epoch 10/202, Training Loss: 0.34531813859939575
# Epoch 10/202, Validation Loss: 0.8861116766929626
# Epoch 11/202, Training Loss: 0.34567564725875854
# Epoch 11/202, Validation Loss: 0.8301410675048828
# Epoch 12/202, Training Loss: 0.35781699419021606
# Epoch 12/202, Validation Loss: 0.7730163931846619
# Epoch 13/202, Training Loss: 0.40571826696395874
# Epoch 13/202, Validation Loss: 0.7317560315132141
# Epoch 14/202, Training Loss: 0.21081751585006714
# Epoch 14/202, Validation Loss: 0.7011278867721558
# Epoch 15/202, Training Loss: 0.2356604039669037
# Epoch 15/202, Validation Loss: 0.6736124753952026
# Epoch 16/202, Training Loss: 0.32237809896469116
# Epoch 16/202, Validation Loss: 0.6495128870010376
# Epoch 17/202, Training Loss: 0.5489157438278198
# Epoch 17/202, Validation Loss: 0.6313611268997192
# Epoch 18/202, Training Loss: 0.27236247062683105
# Epoch 18/202, Validation Loss: 0.6088756918907166
# Epoch 19/202, Training Loss: 0.2974618971347809
# Epoch 19/202, Validation Loss: 0.5819360613822937
# Epoch 20/202, Training Loss: 0.29887765645980835
# Epoch 20/202, Validation Loss: 0.5618392825126648
# Epoch 21/202, Training Loss: 0.2434898167848587
# Epoch 21/202, Validation Loss: 0.5512204170227051
# Epoch 22/202, Training Loss: 0.2641471326351166
# Epoch 22/202, Validation Loss: 0.5442184805870056
# Epoch 23/202, Training Loss: 0.1585906594991684
# Epoch 23/202, Validation Loss: 0.5446684956550598
# Epoch 24/202, Training Loss: 0.1679607480764389
# Epoch 24/202, Validation Loss: 0.5473376512527466
# Epoch 25/202, Training Loss: 0.20948153734207153
# Epoch 25/202, Validation Loss: 0.5439042448997498
# Epoch 26/202, Training Loss: 0.12578530609607697
# Epoch 26/202, Validation Loss: 0.5368455648422241
# Epoch 27/202, Training Loss: 0.18317869305610657
# Epoch 27/202, Validation Loss: 0.520684540271759
# Epoch 28/202, Training Loss: 0.16195401549339294
# Epoch 28/202, Validation Loss: 0.5036349892616272
# Epoch 29/202, Training Loss: 0.20851865410804749
# Epoch 29/202, Validation Loss: 0.4814966022968292
# Epoch 30/202, Training Loss: 0.13907139003276825
# Epoch 30/202, Validation Loss: 0.46395617723464966
# Epoch 31/202, Training Loss: 0.2036542296409607
# Epoch 31/202, Validation Loss: 0.44693130254745483
# Epoch 32/202, Training Loss: 0.1300332397222519
# Epoch 32/202, Validation Loss: 0.43459266424179077
# Epoch 33/202, Training Loss: 0.16183307766914368
# Epoch 33/202, Validation Loss: 0.4224701225757599
# Epoch 34/202, Training Loss: 0.20022307336330414
# Epoch 34/202, Validation Loss: 0.4141979217529297
# Epoch 35/202, Training Loss: 0.1278732717037201
# Epoch 35/202, Validation Loss: 0.4100138247013092
# Epoch 36/202, Training Loss: 0.12380746752023697
# Epoch 36/202, Validation Loss: 0.4088488221168518
# Epoch 37/202, Training Loss: 0.1909179389476776
# Epoch 37/202, Validation Loss: 0.40489432215690613
# Epoch 38/202, Training Loss: 0.14062689244747162
# Epoch 38/202, Validation Loss: 0.4006251096725464
# Epoch 39/202, Training Loss: 0.17529530823230743
# Epoch 39/202, Validation Loss: 0.39652636647224426
# Epoch 40/202, Training Loss: 0.1067807525396347
# Epoch 40/202, Validation Loss: 0.3924686312675476
# Epoch 41/202, Training Loss: 0.16373325884342194
# Epoch 41/202, Validation Loss: 0.3889605402946472
# Epoch 42/202, Training Loss: 0.12124306708574295
# Epoch 42/202, Validation Loss: 0.3830476701259613
# Epoch 43/202, Training Loss: 0.10102216899394989
# Epoch 43/202, Validation Loss: 0.37548089027404785
# Epoch 44/202, Training Loss: 0.09499582648277283
# Epoch 44/202, Validation Loss: 0.36705830693244934
# Epoch 45/202, Training Loss: 0.13735857605934143
# Epoch 45/202, Validation Loss: 0.3584211766719818
# Epoch 46/202, Training Loss: 0.1124020665884018
# Epoch 46/202, Validation Loss: 0.3504471182823181
# Epoch 47/202, Training Loss: 0.13228431344032288
# Epoch 47/202, Validation Loss: 0.341752827167511
# Epoch 48/202, Training Loss: 0.11627696454524994
# Epoch 48/202, Validation Loss: 0.3348900079727173
# Epoch 49/202, Training Loss: 0.10844621807336807
# Epoch 49/202, Validation Loss: 0.3279414176940918
# Epoch 50/202, Training Loss: 0.11625686287879944
# Epoch 50/202, Validation Loss: 0.32346710562705994
# Epoch 51/202, Training Loss: 0.13033823668956757
# Epoch 51/202, Validation Loss: 0.3218890130519867
# Epoch 52/202, Training Loss: 0.12415101379156113
# Epoch 52/202, Validation Loss: 0.3198891878128052
# Epoch 53/202, Training Loss: 0.14484041929244995
# Epoch 53/202, Validation Loss: 0.31377410888671875
# Epoch 54/202, Training Loss: 0.1619505137205124
# Epoch 54/202, Validation Loss: 0.3060961067676544
# Epoch 55/202, Training Loss: 0.07251963764429092
# Epoch 55/202, Validation Loss: 0.30121123790740967
# Epoch 56/202, Training Loss: 0.1119922623038292
# Epoch 56/202, Validation Loss: 0.2961599826812744
# Epoch 57/202, Training Loss: 0.10408540070056915
# Epoch 57/202, Validation Loss: 0.29289036989212036
# Epoch 58/202, Training Loss: 0.15909063816070557
# Epoch 58/202, Validation Loss: 0.28842344880104065
# Epoch 59/202, Training Loss: 0.10945554822683334
# Epoch 59/202, Validation Loss: 0.28569144010543823
# Epoch 60/202, Training Loss: 0.10253632813692093
# Epoch 60/202, Validation Loss: 0.28314274549484253
# Epoch 61/202, Training Loss: 0.07831140607595444
# Epoch 61/202, Validation Loss: 0.28303468227386475
# Epoch 62/202, Training Loss: 0.10350414365530014
# Epoch 62/202, Validation Loss: 0.2807632088661194
# Epoch 63/202, Training Loss: 0.1082962155342102
# Epoch 63/202, Validation Loss: 0.27626800537109375
# Epoch 64/202, Training Loss: 0.12373475730419159
# Epoch 64/202, Validation Loss: 0.26938045024871826
# Epoch 65/202, Training Loss: 0.09327875077724457
# Epoch 65/202, Validation Loss: 0.26653584837913513
# Epoch 66/202, Training Loss: 0.07745885848999023
# Epoch 66/202, Validation Loss: 0.2676590383052826
# Epoch 67/202, Training Loss: 0.10348671674728394
# Epoch 67/202, Validation Loss: 0.2673611044883728
# Epoch 68/202, Training Loss: 0.08868098258972168
# Epoch 68/202, Validation Loss: 0.26591604948043823
# Epoch 69/202, Training Loss: 0.10483390837907791
# Epoch 69/202, Validation Loss: 0.26480481028556824
# Epoch 70/202, Training Loss: 0.08832855522632599
# Epoch 70/202, Validation Loss: 0.2635031044483185
# Epoch 71/202, Training Loss: 0.0792711153626442
# Epoch 71/202, Validation Loss: 0.26540395617485046
# Epoch 72/202, Training Loss: 0.10199616849422455
# Epoch 72/202, Validation Loss: 0.27163711190223694
# Epoch 73/202, Training Loss: 0.1278047263622284
# Epoch 73/202, Validation Loss: 0.27563613653182983
# Epoch 74/202, Training Loss: 0.12262085825204849
# Epoch 74/202, Validation Loss: 0.2734712064266205
# Epoch 75/202, Training Loss: 0.08086849004030228
# Epoch 75/202, Validation Loss: 0.26670366525650024
# Epoch 76/202, Training Loss: 0.07824617624282837
# Epoch 76/202, Validation Loss: 0.25757867097854614
# Epoch 77/202, Training Loss: 0.07182750850915909
# Epoch 77/202, Validation Loss: 0.24989117681980133
# Epoch 78/202, Training Loss: 0.09464424848556519
# Epoch 78/202, Validation Loss: 0.24022641777992249
# Epoch 79/202, Training Loss: 0.09245455265045166
# Epoch 79/202, Validation Loss: 0.23231421411037445
# Epoch 80/202, Training Loss: 0.09649059176445007
# Epoch 80/202, Validation Loss: 0.2269035279750824
# Epoch 81/202, Training Loss: 0.07973441481590271
# Epoch 81/202, Validation Loss: 0.22257404029369354
# Epoch 82/202, Training Loss: 0.11299820244312286
# Epoch 82/202, Validation Loss: 0.21951526403427124
# Epoch 83/202, Training Loss: 0.08820734918117523
# Epoch 83/202, Validation Loss: 0.21881020069122314
# Epoch 84/202, Training Loss: 0.1227487325668335
# Epoch 84/202, Validation Loss: 0.2193795144557953
# Epoch 85/202, Training Loss: 0.07193383574485779
# Epoch 85/202, Validation Loss: 0.2223411500453949
# Epoch 86/202, Training Loss: 0.09803538024425507
# Epoch 86/202, Validation Loss: 0.2246565967798233
# Epoch 87/202, Training Loss: 0.07198679447174072
# Epoch 87/202, Validation Loss: 0.22198447585105896
# Epoch 88/202, Training Loss: 0.09322640299797058
# Epoch 88/202, Validation Loss: 0.2170858383178711
# Epoch 89/202, Training Loss: 0.06211518496274948
# Epoch 89/202, Validation Loss: 0.21429897844791412
# Epoch 90/202, Training Loss: 0.09256960451602936
# Epoch 90/202, Validation Loss: 0.2101830244064331
# Epoch 91/202, Training Loss: 0.07040608674287796
# Epoch 91/202, Validation Loss: 0.2051801234483719
# Epoch 92/202, Training Loss: 0.06291200965642929
# Epoch 92/202, Validation Loss: 0.2007710337638855
# Epoch 93/202, Training Loss: 0.06312225759029388
# Epoch 93/202, Validation Loss: 0.19963636994361877
# Epoch 94/202, Training Loss: 0.10266727954149246
# Epoch 94/202, Validation Loss: 0.20102562010288239
# Epoch 95/202, Training Loss: 0.055723562836647034
# Epoch 95/202, Validation Loss: 0.2061561644077301
# Epoch 96/202, Training Loss: 0.07376783341169357
# Epoch 96/202, Validation Loss: 0.21008609235286713
# Epoch 97/202, Training Loss: 0.10092537850141525
# Epoch 97/202, Validation Loss: 0.20580045878887177
# Epoch 98/202, Training Loss: 0.06130819767713547
# Epoch 98/202, Validation Loss: 0.2001504898071289
# Epoch 99/202, Training Loss: 0.05644994229078293
# Epoch 99/202, Validation Loss: 0.19566833972930908
# Epoch 100/202, Training Loss: 0.1370536983013153
# Epoch 100/202, Validation Loss: 0.1947598159313202
# Epoch 101/202, Training Loss: 0.07528319954872131
# Epoch 101/202, Validation Loss: 0.19858898222446442
# Epoch 102/202, Training Loss: 0.07100394368171692
# Epoch 102/202, Validation Loss: 0.19944801926612854
# Epoch 103/202, Training Loss: 0.06625031679868698
# Epoch 103/202, Validation Loss: 0.20055657625198364
# Epoch 104/202, Training Loss: 0.0658578872680664
# Epoch 104/202, Validation Loss: 0.19813351333141327
# Epoch 105/202, Training Loss: 0.08331102132797241
# Epoch 105/202, Validation Loss: 0.19577248394489288
# Epoch 106/202, Training Loss: 0.08737699687480927
# Epoch 106/202, Validation Loss: 0.18967393040657043
# Epoch 107/202, Training Loss: 0.08854597806930542
# Epoch 107/202, Validation Loss: 0.1863548755645752
# Epoch 108/202, Training Loss: 0.07343392819166183
# Epoch 108/202, Validation Loss: 0.18418952822685242
# Epoch 109/202, Training Loss: 0.053021445870399475
# Epoch 109/202, Validation Loss: 0.18421724438667297
# Epoch 110/202, Training Loss: 0.10258321464061737
# Epoch 110/202, Validation Loss: 0.184953972697258
# Epoch 111/202, Training Loss: 0.08450378477573395
# Epoch 111/202, Validation Loss: 0.1852618008852005
# Epoch 112/202, Training Loss: 0.06501877307891846
# Epoch 112/202, Validation Loss: 0.18638405203819275
# Epoch 113/202, Training Loss: 0.0825720876455307
# Epoch 113/202, Validation Loss: 0.18799299001693726
# Epoch 114/202, Training Loss: 0.05982241779565811
# Epoch 114/202, Validation Loss: 0.1869983971118927
# Epoch 115/202, Training Loss: 0.07266511768102646
# Epoch 115/202, Validation Loss: 0.18355804681777954
# Epoch 116/202, Training Loss: 0.06307396292686462
# Epoch 116/202, Validation Loss: 0.17929154634475708
# Epoch 117/202, Training Loss: 0.07147851586341858
# Epoch 117/202, Validation Loss: 0.17354685068130493
# Epoch 118/202, Training Loss: 0.09353304654359818
# Epoch 118/202, Validation Loss: 0.16640222072601318
# Epoch 119/202, Training Loss: 0.06286691129207611
# Epoch 119/202, Validation Loss: 0.162805438041687
# Epoch 120/202, Training Loss: 0.06021075323224068
# Epoch 120/202, Validation Loss: 0.16142955422401428
# Epoch 121/202, Training Loss: 0.0998830646276474
# Epoch 121/202, Validation Loss: 0.1628817915916443
# Epoch 122/202, Training Loss: 0.06429794430732727
# Epoch 122/202, Validation Loss: 0.16488222777843475
# Epoch 123/202, Training Loss: 0.06445331126451492
# Epoch 123/202, Validation Loss: 0.16422949731349945
# Epoch 124/202, Training Loss: 0.04401352256536484
# Epoch 124/202, Validation Loss: 0.1676940619945526
# Epoch 125/202, Training Loss: 0.051226966083049774
# Epoch 125/202, Validation Loss: 0.17518498003482819
# Epoch 126/202, Training Loss: 0.046144627034664154
# Epoch 126/202, Validation Loss: 0.17799486219882965
# Epoch 127/202, Training Loss: 0.08073434233665466
# Epoch 127/202, Validation Loss: 0.17070001363754272
# Epoch 128/202, Training Loss: 0.07331353425979614
# Epoch 128/202, Validation Loss: 0.16001960635185242
# Epoch 129/202, Training Loss: 0.07668743282556534
# Epoch 129/202, Validation Loss: 0.1546829640865326
# Epoch 130/202, Training Loss: 0.03937109559774399
# Epoch 130/202, Validation Loss: 0.15512657165527344
# Epoch 131/202, Training Loss: 0.07150967419147491
# Epoch 131/202, Validation Loss: 0.15469825267791748
# Epoch 132/202, Training Loss: 0.0696873664855957
# Epoch 132/202, Validation Loss: 0.15230630338191986
# Epoch 133/202, Training Loss: 0.06394091248512268
# Epoch 133/202, Validation Loss: 0.15274818241596222
# Epoch 134/202, Training Loss: 0.06723115593194962
# Epoch 134/202, Validation Loss: 0.15432345867156982
# Epoch 135/202, Training Loss: 0.059872329235076904
# Epoch 135/202, Validation Loss: 0.1556340456008911
# Epoch 136/202, Training Loss: 0.054477348923683167
# Epoch 136/202, Validation Loss: 0.1575535237789154
# Epoch 137/202, Training Loss: 0.10057136416435242
# Epoch 137/202, Validation Loss: 0.1592237949371338
# Epoch 138/202, Training Loss: 0.07053488492965698
# Epoch 138/202, Validation Loss: 0.16054147481918335
# Epoch 139/202, Training Loss: 0.06728561222553253
# Epoch 139/202, Validation Loss: 0.1555681675672531
# Epoch 140/202, Training Loss: 0.08519160747528076
# Epoch 140/202, Validation Loss: 0.1463320255279541
# Epoch 141/202, Training Loss: 0.08195539563894272
# Epoch 141/202, Validation Loss: 0.14092636108398438
# Epoch 142/202, Training Loss: 0.0960417091846466
# Epoch 142/202, Validation Loss: 0.1435873806476593
# Epoch 143/202, Training Loss: 0.16920216381549835
# Epoch 143/202, Validation Loss: 0.14849048852920532
# Epoch 144/202, Training Loss: 0.06613270938396454
# Epoch 144/202, Validation Loss: 0.15080559253692627
# Epoch 145/202, Training Loss: 0.08658972382545471
# Epoch 145/202, Validation Loss: 0.15473893284797668
# Epoch 146/202, Training Loss: 0.05897314101457596
# Epoch 146/202, Validation Loss: 0.16021890938282013
# Epoch 147/202, Training Loss: 0.06682377308607101
# Epoch 147/202, Validation Loss: 0.1650218665599823
# Epoch 148/202, Training Loss: 0.06564005464315414
# Epoch 148/202, Validation Loss: 0.16744238138198853
# Epoch 149/202, Training Loss: 0.05301271006464958
# Epoch 149/202, Validation Loss: 0.1657618284225464
# Epoch 150/202, Training Loss: 0.06281200051307678
# Epoch 150/202, Validation Loss: 0.16116520762443542
# Epoch 151/202, Training Loss: 0.05271761864423752
# Epoch 151/202, Validation Loss: 0.15311284363269806
# Epoch 152/202, Training Loss: 0.06487669795751572
# Epoch 152/202, Validation Loss: 0.1472376435995102
# Epoch 153/202, Training Loss: 0.0756596177816391
# Epoch 153/202, Validation Loss: 0.14419738948345184
# Epoch 154/202, Training Loss: 0.07048659771680832
# Epoch 154/202, Validation Loss: 0.14501306414604187
# Epoch 155/202, Training Loss: 0.06521369516849518
# Epoch 155/202, Validation Loss: 0.14513535797595978
# Epoch 156/202, Training Loss: 0.06648997217416763
# Epoch 156/202, Validation Loss: 0.1401020884513855
# Epoch 157/202, Training Loss: 0.09960813820362091
# Epoch 157/202, Validation Loss: 0.13689649105072021
# Epoch 158/202, Training Loss: 0.06583745777606964
# Epoch 158/202, Validation Loss: 0.13600170612335205
# Epoch 159/202, Training Loss: 0.04448797181248665
# Epoch 159/202, Validation Loss: 0.13871124386787415
# Epoch 160/202, Training Loss: 0.07669900357723236
# Epoch 160/202, Validation Loss: 0.14670228958129883
# Epoch 161/202, Training Loss: 0.0569271519780159
# Epoch 161/202, Validation Loss: 0.15327277779579163
# Epoch 162/202, Training Loss: 0.05732577294111252
# Epoch 162/202, Validation Loss: 0.1546994149684906
# Epoch 163/202, Training Loss: 0.06604577600955963
# Epoch 163/202, Validation Loss: 0.15387514233589172
# Epoch 164/202, Training Loss: 0.05298886075615883
# Epoch 164/202, Validation Loss: 0.1491253823041916
# Epoch 165/202, Training Loss: 0.04505009949207306
# Epoch 165/202, Validation Loss: 0.14330415427684784
# Epoch 166/202, Training Loss: 0.09900034964084625
# Epoch 166/202, Validation Loss: 0.14195933938026428
# Epoch 167/202, Training Loss: 0.07089832425117493
# Epoch 167/202, Validation Loss: 0.13988980650901794
# Epoch 168/202, Training Loss: 0.05230684578418732
# Epoch 168/202, Validation Loss: 0.13862363994121552
# Epoch 169/202, Training Loss: 0.05671801418066025
# Epoch 169/202, Validation Loss: 0.13635122776031494
# Epoch 170/202, Training Loss: 0.053289372473955154
# Epoch 170/202, Validation Loss: 0.1333766132593155
# Epoch 171/202, Training Loss: 0.04490525275468826
# Epoch 171/202, Validation Loss: 0.13217316567897797
# Epoch 172/202, Training Loss: 0.07650627195835114
# Epoch 172/202, Validation Loss: 0.13236004114151
# Epoch 173/202, Training Loss: 0.06821896135807037
# Epoch 173/202, Validation Loss: 0.1350782811641693
# Epoch 174/202, Training Loss: 0.12124013155698776
# Epoch 174/202, Validation Loss: 0.13945768773555756
# Epoch 175/202, Training Loss: 0.054938189685344696
# Epoch 175/202, Validation Loss: 0.14783041179180145
# Epoch 176/202, Training Loss: 0.04092756658792496
# Epoch 176/202, Validation Loss: 0.15096524357795715
# Epoch 177/202, Training Loss: 0.04758626967668533
# Epoch 177/202, Validation Loss: 0.14606845378875732
# Epoch 178/202, Training Loss: 0.058203019201755524
# Epoch 178/202, Validation Loss: 0.13912561535835266
# Epoch 179/202, Training Loss: 0.057715922594070435
# Epoch 179/202, Validation Loss: 0.13399450480937958
# Epoch 180/202, Training Loss: 0.05507567524909973
# Epoch 180/202, Validation Loss: 0.13386715948581696
# Epoch 181/202, Training Loss: 0.04776598513126373
# Epoch 181/202, Validation Loss: 0.13335265219211578
# Epoch 182/202, Training Loss: 0.06089866906404495
# Epoch 182/202, Validation Loss: 0.12889587879180908
# Epoch 183/202, Training Loss: 0.07099498063325882
# Epoch 183/202, Validation Loss: 0.12677893042564392
# Epoch 184/202, Training Loss: 0.05206015333533287
# Epoch 184/202, Validation Loss: 0.13565391302108765
# Epoch 185/202, Training Loss: 0.06719086319208145
# Epoch 185/202, Validation Loss: 0.14682698249816895
# Epoch 186/202, Training Loss: 0.07712225615978241
# Epoch 186/202, Validation Loss: 0.14725248515605927
# Epoch 187/202, Training Loss: 0.06838005781173706
# Epoch 187/202, Validation Loss: 0.14581707119941711
# Epoch 188/202, Training Loss: 0.0708288922905922
# Epoch 188/202, Validation Loss: 0.14003325998783112
# Epoch 189/202, Training Loss: 0.04967594891786575
# Epoch 189/202, Validation Loss: 0.13031098246574402
# Epoch 190/202, Training Loss: 0.04984705522656441
# Epoch 190/202, Validation Loss: 0.12334456294775009
# Epoch 191/202, Training Loss: 0.048632897436618805
# Epoch 191/202, Validation Loss: 0.12108531594276428
# Epoch 192/202, Training Loss: 0.05777701735496521
# Epoch 192/202, Validation Loss: 0.12046638131141663
# Epoch 193/202, Training Loss: 0.03637772798538208
# Epoch 193/202, Validation Loss: 0.1197294294834137
# Epoch 194/202, Training Loss: 0.0507611520588398
# Epoch 194/202, Validation Loss: 0.11759967356920242
# Epoch 195/202, Training Loss: 0.0670379251241684
# Epoch 195/202, Validation Loss: 0.11594895273447037
# Epoch 196/202, Training Loss: 0.057657063007354736
# Epoch 196/202, Validation Loss: 0.12160676717758179
# Epoch 197/202, Training Loss: 0.05341570824384689
# Epoch 197/202, Validation Loss: 0.1268630176782608
# Epoch 198/202, Training Loss: 0.047408394515514374
# Epoch 198/202, Validation Loss: 0.1292538046836853
# Epoch 199/202, Training Loss: 0.05016423761844635
# Epoch 199/202, Validation Loss: 0.12942077219486237
# Epoch 200/202, Training Loss: 0.059328723698854446
# Epoch 200/202, Validation Loss: 0.12435289472341537
# Epoch 201/202, Training Loss: 0.05095759406685829
# Epoch 201/202, Validation Loss: 0.11712837964296341
# Epoch 202/202, Training Loss: 0.04431962966918945
# Epoch 202/202, Validation Loss: 0.1160447895526886
# Training is done!
